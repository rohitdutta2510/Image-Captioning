# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pickle
import numpy as np
import pandas as pd
import re
from tqdm.notebook import tqdm
import csv
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, Dropout, add

from nltk.translate.bleu_score import corpus_bleu, SmoothingFunction
# !pip install pycocoevalcap
# !pip install rouge
from rouge import Rouge
from tqdm import tqdm
from pycocoevalcap.cider.cider import Cider
from pycocoevalcap.spice.spice import Spice


# !pip install git+https://github.com/salaniz/pycocoevalcap
# Out:
# Collecting pycocoevalcap
#   Downloading pycocoevalcap-1.2-py3-none-any.whl (104.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from pycocoevalcap) (2.0.7)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools>=2.0.2->pycocoevalcap) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pycocotools>=2.0.2->pycocoevalcap) (1.25.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (1.16.0)
# Installing collected packages: pycocoevalcap
# Successfully installed pycocoevalcap-1.2
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge) (1.16.0)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1
# Collecting git+https://github.com/salaniz/pycocoevalcap
#   Cloning https://github.com/salaniz/pycocoevalcap to /tmp/pip-req-build-6ibj30a5
#   Running command git clone --filter=blob:none --quiet https://github.com/salaniz/pycocoevalcap /tmp/pip-req-build-6ibj30a5
#   Resolved https://github.com/salaniz/pycocoevalcap to commit a24f74c408c918f1f4ec34e9514bc8a76ce41ffd
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from pycocoevalcap==1.2) (2.0.7)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools>=2.0.2->pycocoevalcap==1.2) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pycocotools>=2.0.2->pycocoevalcap==1.2) (1.25.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (1.16.0)

# %% [markdown]
# **Defining the directories**

# %%
# Define paths to CSV files and image folders
folder_path = '/content/drive/MyDrive/custom_captions_dataset/'
train_csv_file = folder_path + 'train.csv'
train_img_folder = folder_path + 'train'
test_csv_file = folder_path + 'test.csv'
test_img_folder = folder_path + 'test'
val_csv_file = folder_path + 'val.csv'
val_img_folder = folder_path + 'val'

# %%
def get_preprocessed_caption(caption): # preprocess the captions
    caption = caption.replace('\s+', ' ')
    caption = caption.replace('[^A-Za-z]', '')
    caption = caption.strip().lower()
    caption = "startseq " + caption + " endseq"
    return caption

# %% [markdown]
# **Load Caption**

# %%
def load_caption(csv_file, img_folder):

    data = pd.read_csv(csv_file) # Load CSV file
    captions = []
    img_dict = {}

    for index, row in data.iterrows():

        image_path = os.path.join(img_folder, row['filename'])
        image_name = image_path.split('/')[-1].split('.')[0]
        caption = get_preprocessed_caption(row['caption'])
        captions.append(caption)
        img_dict[image_name] = caption

    return img_dict

# %% [markdown]
# **Load IMAGES**

# %%
def load_images(directory):
  features = {}
  for img_name in tqdm(os.listdir(directory)):

      img_path = directory + '/' + img_name # load the image from file
      image = load_img(img_path, target_size=(224, 224))
      image = img_to_array(image)  # convert image pixels to numpy array
      image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2])) # reshape data for model
      image = preprocess_input(image) # preprocess image for vgg
      image_id = img_name.split('.')[0] # get image ID
      features[image_id] = image  # feature

  return features

# %% [markdown]
# **Instantiating VGG16 as encoder CNN model**

# %%
# load vgg16 model
model_vgg16 = VGG16()
model_vgg16 = Model(inputs=model_vgg16.inputs, outputs=model_vgg16.layers[-2].output) # restructure the model
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467096/553467096 [==============================] - 4s 0us/step

# %%
train_img = load_images(train_img_folder)
test_img = load_images(test_img_folder)
val_img = load_images(val_img_folder)
# Out:
# 100%|██████████| 5715/5715 [02:26<00:00, 38.93it/s]
# 100%|██████████| 1009/1009 [00:32<00:00, 31.46it/s]
# 100%|██████████| 946/946 [00:31<00:00, 29.76it/s]

# %%
# Dumping the images into pickle files
with open(folder_path + 'train_img_2.pickle', 'wb') as handle:
  pickle.dump(train_img, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open(folder_path + 'test_img_2.pickle', 'wb') as handle:
  pickle.dump(test_img, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open(folder_path + 'val_img_2.pickle', 'wb') as handle:
  pickle.dump(val_img, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open(folder_path + 'train_img_2.pickle', 'rb') as handle:
  train_img = pickle.load(handle)

with open(folder_path + 'test_img_2.pickle', 'rb') as handle:
  test_img = pickle.load(handle)

with open(folder_path + 'val_img_2.pickle', 'rb') as handle:
  val_img = pickle.load(handle)

# %%
# Load data
train_mapping = load_caption(train_csv_file, train_img_folder)
test_mapping = load_caption(test_csv_file, test_img_folder)
val_mapping = load_caption(val_csv_file, val_img_folder)
print("Training data: {} ".format(len(train_mapping)))
print("Testing data: {} ".format(len(test_mapping)))
print("Validation data: {} ".format(len(val_mapping)))
# Out:
# Training data: 5715
# Testing data: 928
# Validation data: 946

# %%
all_captions = list(train_mapping.values())
# tokenize the text
tokenizer = Tokenizer()
tokenizer.fit_on_texts(all_captions)
vocab_size = len(tokenizer.word_index)

# get maximum length of the caption available
max_length = max(len(caption.split()) for caption in all_captions)
max_length

# %%
train_img_id = list(train_mapping.keys())
test_img_id = list(test_mapping.keys())
val_img_id = list(val_mapping.keys())

# %% [markdown]
# **GENERATOR FUNCTION**

# %%
# create data generator to get data in batch (avoids session crash)
def data_generator(data_keys, mapping, images, tokenizer, max_length, vocab_size, batch_size, model_vgg16):

    X1, X2, y = list(), list(), list()
    n = 0
    while 1:
        for key in data_keys:
            n += 1
            caption = mapping[key]
            seq = tokenizer.texts_to_sequences([caption])[0]
            feature = model_vgg16.predict(images[key], verbose=0)
            # split the sequence into X, y pairs
            for i in range(1, len(seq)):

                in_seq, out_seq = seq[:i], seq[i] # split into input and output pairs
                in_seq = pad_sequences([in_seq], maxlen=max_length)[0] # pad input sequence
                out_seq = to_categorical([out_seq], num_classes=vocab_size)[0] # encode output sequence
                # store the sequences
                X1.append(feature[0])
                X2.append(in_seq)
                y.append(out_seq)

            if n == batch_size:
                if not X1 or not X2 or not y: # Skip empty batches
                    X1, X2, y = list(), list(), list()
                    n = 0
                    continue
                X1, X2, y = np.array(X1), np.array(X2), np.array(y)
                yield [X1, X2], y
                X1, X2, y = list(), list(), list()
                n = 0

# %% [markdown]
# **MODEL**

# %%
# encoder model
# image feature layers
inputs1 = Input(shape=(4096,))
fe1 = Dropout(0.4)(inputs1)
fe2 = Dense(256, activation='relu')(fe1)

# sequence feature layers
inputs2 = Input(shape=(max_length,))
se1 = Embedding(vocab_size, 256, mask_zero=True)(inputs2)
se2 = Dropout(0.4)(se1)
se3 = LSTM(256)(se2)

# decoder model
decoder1 = add([fe2, se3])
decoder2 = Dense(256, activation='relu')(decoder1)
outputs = Dense(vocab_size, activation='softmax')(decoder2)

model = Model(inputs=[inputs1, inputs2], outputs=outputs)
model.compile(loss='categorical_crossentropy', optimizer='adam')

# %%
# plot the model
plot_model(model, show_shapes=True)

# %%
def idx_to_word(integer, tokenizer):
    for word, index in tokenizer.word_index.items():
        if index == integer:
            return word
    return None

# %% [markdown]
# **FUNCTION to predict captions**

# %%
# generate caption for an image
def predict_caption(model, image, tokenizer, max_length):
    in_text = 'startseq'
    for i in range(max_length):
        sequence = tokenizer.texts_to_sequences([in_text])[0] # encode input sequence
        sequence = pad_sequences([sequence], max_length) # pad the sequence
        feature = model_vgg16.predict(image, verbose=0)
        yhat = model.predict([feature, sequence], verbose=0) # predict next word
        yhat = np.argmax(yhat) # get index with high probability
        word = idx_to_word(yhat, tokenizer) # convert index to word

        if word is None: # stop if word not found
            break
        in_text += " " + word

        if word == 'endseq': # stop if we reach end tag
            break

    return in_text

# %% [markdown]
# **SCORE METRICS**

# %%
def compute_cider_score(actual, predicted):
    cider_scorer = Cider()
    score , cider_scores = cider_scorer.compute_score(actual, predicted)
    # print(score, cider_scores)
    # return sum(cider_scores) / len(cider_scores)
    return score # 1.2

def compute_spice_score(actual, predicted):
    spice_scorer = Spice()
    spice_score, _ = spice_scorer.compute_score(actual, predicted)
    return spice_score  # 0.05

def compute_rouge_l_score(actual, predicted):
    rouge = Rouge()
    true_cap = [caption[0] for caption in actual]
    pred_cap = [caption[0] for caption in predicted]
    scores = rouge.get_scores(pred_cap, true_cap, avg=True)
    return scores['rouge-l']['f']  # 0.4 - 0.5

import time

def compute_spice_score_with_progress(actual_dict, predicted_dict):
    spice_scorer = Spice()
    num_images = len(actual_dict)
    progress_interval = num_images // 100  # Update progress every 10% of images processed
    spice_scores = []

    print("Computing SPICE score...")
    start_time = time.time()
    for i, (img_id, actual_captions) in enumerate(actual_dict.items(), 1):
        spice_score, _ = spice_scorer.compute_score({img_id: actual_captions}, {img_id: predicted_dict[img_id]})
        spice_scores.append(spice_score)

        if i % progress_interval == 0 or i == num_images:
            elapsed_time = time.time() - start_time
            print(f"Progress: {i}/{num_images} images processed. Elapsed time: {elapsed_time:.2f} seconds")

    average_spice_score = sum(spice_scores) / num_images
    print("SPICE score calculation completed.")
    return average_spice_score

# %% [markdown]
# **EVALUATE**

# %%
import random
def evaluate_model(model, val_img_id, val_img, val_mapping):
    actual, predicted = {}, {}

    for key in tqdm(random.sample(val_img_id, 5)):  # Iterate through the first item for valing
        actual[key] = [val_mapping[key]]  # Wrap ground truth captions in a list
        predicted[key] = [predict_caption(model, val_img[key], tokenizer, max_length)]  # Wrap the generated caption in a list
        print(actual[key])
        print(predicted[key])

    return compute_rouge_l_score(list(actual.values()), list(predicted.values()))

# %%
model.summary()

# %% [markdown]
# **TRAINING THE MODEL**

# %%
# train the model
epochs = 8
batch_size = 32
steps = len(train_img_id) // batch_size

best_val_score = float('-inf')
best_model_path = 'best_model_t1.pickle'

for i in range(epochs):
    generator = data_generator(train_img_id, train_mapping, train_img, tokenizer, max_length, vocab_size, batch_size, model_vgg16) # create data generator
    model.fit(generator, epochs=1, steps_per_epoch=steps, verbose=1) # fit for one epoch
    val_score = evaluate_model(model, val_img_id, val_img, val_mapping) # Evaluate model on validation data

    # Save model if it has the best validation score so far
    if val_score > best_val_score:
        best_val_score = val_score
        with open(folder_path + best_model_path, 'wb') as handle:
            pickle.dump(model, handle, protocol=pickle.HIGHEST_PROTOCOL)
        print("Saved model with best validation score:", best_val_score)

# %%
best_model_path='best_model_t1.pickle'

# %% [markdown]
# Loading the best model stored above

# %%
with open(folder_path + best_model_path, 'rb') as handle:
    best_model = pickle.load(handle)

# %%
from PIL import Image
import matplotlib.pyplot as plt
# test_mapping['test_2']
img_path=f'{folder_path}test/test_1.jpg'
image = Image.open(img_path)
plt.imshow(image)

test_mapping['test_1']

# %%
# create the CSV file (Structure only)


# with open(folder_path + 't1_predictions_v3.csv', mode='w', newline='') as file:
#     writer = csv.writer(file)
#     writer.writerow(['serial','img_id', 'actual_caption', 'predicted_caption'])

# %% [markdown]
# **Predicted captions on TEST DATA**

# %%
from tqdm import tqdm
import csv
actual, predicted = {}, {}

# Save the data into a CSV file

count=0
for key in test_img_id:  # Iterate through the first item for testing
    count+=1
    actual[key] = [test_mapping[key]]  # Wrap ground truth captions in a list
    predicted[key] = [predict_caption(best_model, test_img[key], tokenizer, max_length)]  # Wrap the generated caption in a list
    with open(folder_path + 't1_predictions_v3.csv', mode='a', newline='') as file:
        writer = csv.writer(file)
        writer.writerow([count,key, actual[key][0], predicted[key][0]])
    print(f'{count} done')

# %% [markdown]
# Loading the predicted captions

# %%
def remove_start_end(sentence):
    words=sentence.split(' ')
    return " ".join(words[1:-1])


df_pred=pd.read_csv(folder_path + 't1_predictions_v3.csv')
image_id=df_pred['img_id']
actual_caption=df_pred['actual_caption']
pred_caption=df_pred['predicted_caption']


actual_caption=actual_caption.apply(remove_start_end)
pred_caption=pred_caption.apply(remove_start_end)

# %%
image_actual_dict = {}
for img_id, actual_cap in zip(image_id, actual_caption):
    if img_id in image_actual_dict:
        image_actual_dict[img_id].append(actual_cap)
    else:
        image_actual_dict[img_id] = [actual_cap]


image_pred_dict = {}
for img_id, pred_cap in zip(image_id, pred_caption):
    if img_id in image_pred_dict:
        image_pred_dict[img_id].append(pred_cap)
    else:
        image_pred_dict[img_id] = [pred_cap]

# %% [markdown]
# **ROGUE-L SCORE**

# %%
rouge_l_score = compute_rouge_l_score(list(image_actual_dict.values()), list(image_pred_dict.values()))
print(f"\nROUGE-L: {rouge_l_score}")
# Out:
# ROUGE-L: 0.35167331036641325

# %% [markdown]
# **CIDEr SCORE**

# %%
cider_score = compute_cider_score(image_actual_dict,image_pred_dict)
print(f"CIDEr: {cider_score}")
# Out:
# CIDEr: 0.05834273241798831

# %% [markdown]
# **SCPICE SCORE**

# %%
# spice_score = compute_spice_score(image_actual_dict, image_pred_dict)
# print(f"SPICE: {spice_score}")
# Out:
# Downloading stanford-corenlp-3.6.0 for SPICE ...
# Progress: 384.5M / 384.5M (100.0%)
# Extracting stanford-corenlp-3.6.0 ...
# Done.

# %%
spice_score = compute_spice_score_with_progress(image_actual_dict, image_pred_dict)
print("SPICE score:", spice_score)
# Out:
# Computing SPICE score...
# Progress: 9/928 images processed. Elapsed time: 29.74 seconds
# Progress: 18/928 images processed. Elapsed time: 163.91 seconds
# Progress: 27/928 images processed. Elapsed time: 412.93 seconds
# Progress: 36/928 images processed. Elapsed time: 769.35 seconds
# Progress: 45/928 images processed. Elapsed time: 951.24 seconds
# Progress: 54/928 images processed. Elapsed time: 1128.94 seconds
# Progress: 63/928 images processed. Elapsed time: 1294.75 seconds
# Progress: 72/928 images processed. Elapsed time: 1618.40 seconds
# Progress: 81/928 images processed. Elapsed time: 2033.41 seconds
# Progress: 90/928 images processed. Elapsed time: 2189.24 seconds
# Progress: 99/928 images processed. Elapsed time: 2522.99 seconds
# Progress: 108/928 images processed. Elapsed time: 2759.10 seconds
# Progress: 117/928 images processed. Elapsed time: 3010.54 seconds
# Progress: 126/928 images processed. Elapsed time: 3185.84 seconds
# Progress: 135/928 images processed. Elapsed time: 3616.18 seconds
# Progress: 144/928 images processed. Elapsed time: 3872.98 seconds
# Progress: 153/928 images processed. Elapsed time: 4127.20 seconds
# Progress: 162/928 images processed. Elapsed time: 4476.69 seconds
# Progress: 171/928 images processed. Elapsed time: 4727.87 seconds
# Progress: 180/928 images processed. Elapsed time: 4913.61 seconds
# Progress: 189/928 images processed. Elapsed time: 5208.67 seconds
# Progress: 198/928 images processed. Elapsed time: 5502.77 seconds
# Progress: 207/928 images processed. Elapsed time: 5702.10 seconds
# Progress: 216/928 images processed. Elapsed time: 6086.39 seconds
# Progress: 225/928 images processed. Elapsed time: 6266.88 seconds
# Progress: 234/928 images processed. Elapsed time: 6449.28 seconds
# Progress: 243/928 images processed. Elapsed time: 6731.19 seconds
# Progress: 252/928 images processed. Elapsed time: 6941.45 seconds
# Progress: 261/928 images processed. Elapsed time: 7362.74 seconds
# Progress: 270/928 images processed. Elapsed time: 7535.67 seconds
# Progress: 279/928 images processed. Elapsed time: 7706.66 seconds
# Progress: 288/928 images processed. Elapsed time: 7869.50 seconds
# Progress: 297/928 images processed. Elapsed time: 8158.98 seconds
# Progress: 306/928 images processed. Elapsed time: 8580.59 seconds
# Progress: 315/928 images processed. Elapsed time: 8835.89 seconds
# Progress: 324/928 images processed. Elapsed time: 9016.09 seconds
# Progress: 333/928 images processed. Elapsed time: 9523.37 seconds
# Progress: 342/928 images processed. Elapsed time: 9759.78 seconds
# Progress: 351/928 images processed. Elapsed time: 10206.49 seconds
# Progress: 360/928 images processed. Elapsed time: 10488.22 seconds
# Progress: 369/928 images processed. Elapsed time: 10815.97 seconds
# Progress: 378/928 images processed. Elapsed time: 10999.62 seconds
# Progress: 387/928 images processed. Elapsed time: 11164.29 seconds
# Progress: 396/928 images processed. Elapsed time: 11335.82 seconds
# Progress: 405/928 images processed. Elapsed time: 11603.33 seconds
# Progress: 414/928 images processed. Elapsed time: 11783.40 seconds
# Progress: 423/928 images processed. Elapsed time: 12060.53 seconds
# Progress: 432/928 images processed. Elapsed time: 12231.69 seconds
# Progress: 441/928 images processed. Elapsed time: 12601.08 seconds
# Progress: 450/928 images processed. Elapsed time: 12774.34 seconds
# Progress: 459/928 images processed. Elapsed time: 13133.09 seconds
# Progress: 468/928 images processed. Elapsed time: 13414.25 seconds
# Progress: 477/928 images processed. Elapsed time: 13601.44 seconds
# Progress: 486/928 images processed. Elapsed time: 13954.58 seconds
# Progress: 495/928 images processed. Elapsed time: 14203.91 seconds
# Progress: 504/928 images processed. Elapsed time: 14388.79 seconds
# Progress: 513/928 images processed. Elapsed time: 14751.69 seconds
# Progress: 522/928 images processed. Elapsed time: 14934.59 seconds
# Progress: 531/928 images processed. Elapsed time: 15113.34 seconds
# Progress: 540/928 images processed. Elapsed time: 15452.73 seconds
# Progress: 549/928 images processed. Elapsed time: 15715.66 seconds
# Progress: 558/928 images processed. Elapsed time: 15893.17 seconds
# Progress: 567/928 images processed. Elapsed time: 16161.56 seconds
# Progress: 576/928 images processed. Elapsed time: 16329.22 seconds
# Progress: 585/928 images processed. Elapsed time: 16487.71 seconds
# Progress: 594/928 images processed. Elapsed time: 16850.97 seconds
# Progress: 603/928 images processed. Elapsed time: 17096.75 seconds
# Progress: 612/928 images processed. Elapsed time: 17427.13 seconds
# Progress: 621/928 images processed. Elapsed time: 17680.10 seconds
# Progress: 630/928 images processed. Elapsed time: 17949.70 seconds
# Progress: 639/928 images processed. Elapsed time: 18112.57 seconds
# Progress: 648/928 images processed. Elapsed time: 18315.51 seconds
# Progress: 657/928 images processed. Elapsed time: 18687.13 seconds
# Progress: 666/928 images processed. Elapsed time: 18935.58 seconds
# Progress: 675/928 images processed. Elapsed time: 19102.64 seconds
# Progress: 684/928 images processed. Elapsed time: 19376.75 seconds
# Progress: 693/928 images processed. Elapsed time: 19636.56 seconds
# Progress: 702/928 images processed. Elapsed time: 19985.16 seconds
# Progress: 711/928 images processed. Elapsed time: 20262.00 seconds
# Progress: 720/928 images processed. Elapsed time: 20520.43 seconds
# Progress: 729/928 images processed. Elapsed time: 20957.31 seconds
# Progress: 738/928 images processed. Elapsed time: 21199.64 seconds
# Progress: 747/928 images processed. Elapsed time: 21462.21 seconds
# Progress: 756/928 images processed. Elapsed time: 21694.65 seconds
# Progress: 765/928 images processed. Elapsed time: 22041.41 seconds
# Progress: 774/928 images processed. Elapsed time: 22214.13 seconds
# Progress: 783/928 images processed. Elapsed time: 22394.17 seconds
# Progress: 792/928 images processed. Elapsed time: 22572.68 seconds
# Progress: 801/928 images processed. Elapsed time: 23121.55 seconds
# Progress: 810/928 images processed. Elapsed time: 23392.84 seconds
# Progress: 819/928 images processed. Elapsed time: 23567.08 seconds
# Progress: 828/928 images processed. Elapsed time: 23841.38 seconds
# Progress: 837/928 images processed. Elapsed time: 24017.58 seconds
# Progress: 846/928 images processed. Elapsed time: 24178.48 seconds
# Progress: 855/928 images processed. Elapsed time: 24539.79 seconds
# Progress: 864/928 images processed. Elapsed time: 24831.03 seconds
# Progress: 873/928 images processed. Elapsed time: 25040.06 seconds
# Progress: 882/928 images processed. Elapsed time: 25312.17 seconds
# Progress: 891/928 images processed. Elapsed time: 25592.13 seconds
# Progress: 900/928 images processed. Elapsed time: 25911.99 seconds
# Progress: 909/928 images processed. Elapsed time: 26178.59 seconds
# Progress: 918/928 images processed. Elapsed time: 26512.80 seconds
# Progress: 927/928 images processed. Elapsed time: 26843.34 seconds
# Progress: 928/928 images processed. Elapsed time: 26868.84 seconds
# SPICE score calculation completed.
# SPICE score: 0.137427499450287

# %%
print("SPICE score:", spice_score)
# Out:
# SPICE score: 0.137427499450287

# %% [markdown]
# **DISPLAY THE OUTPUTs**

# %%
for key in image_actual_dict.keys():
    print("\npic_id - ", key)
    print("original caption - ", remove_start_end(image_actual_dict[key][0]))
    print("predicted caption - ", remove_start_end(image_pred_dict[key][0]))
# Out:
# pic_id -  test_1
# original caption -  a large building with bars on the windows in front of it. there is people walking in front of the building. there is a street in front of the building with many cars on it.
# predicted caption -  this is a picture of a city street there are two people walking on the sidewalk the street is white the street is red and white the street is red and white there are two story buildings on the side of the street there are many buildings on the sidewalk the buildings are green and white the buildings are green and white the buildings are parked on the sidewalk
#
# pic_id -  test_2
# original caption -  a person is skiing through the snow. there is loose snow all around them from him jumping. the person is wearing a yellow snow suit. the person is holding two ski poles in their hands.
# predicted caption -  this is an image of a man the man is wearing a black helmet the man is wearing a black helmet the man is wearing a black helmet the man is wearing a black helmet the man is wearing a black helmet the man is wearing a black helmet the man is wearing a black helmet the man is wearing a black jacket the snow is black
#
# pic_id -  test_3
# original caption -  there is a bed in a room against a wall. there is a brown blanket on top of the bed. there is a small brown book shelf next to the bed. there is a picture hanging on the wall above the shelf.
# predicted caption -  this is an image of a bedroom the bedroom is a hotel the bed is void of furniture the bed is made of wood the bed is made of wood the bed is made of wood the bed is made of wood the bed is made of wood the bed is made of wood the bed is made of wood the bed is made of wood
#
# pic_id -  test_4
# original caption -  a black and red train is on the tracks and has steam coming out off of it. there is another train next to the first train that is orange. there is an overpass over the train tracks with cars on it.
# predicted caption -  a train is pulling into the station the train is white and has a number 52 on the side of the train the train is on a track the train is white and has a red stripe down the side the train is on a track the train is red and white there are wires above the train there is a yellow train on the train tracks
#
# pic_id -  test_5
# original caption -  a white and yellow public transportation bus with "122" on front is stopped with it's doors open. there is a gray car on the street beside the bus. behind the car there is a  building with an "urban outfitters" on the first floor.
# predicted caption -  a large brown bus is parked on a sidewalk the bus is white and has a black and white sign on it the drum is red and has a black and white sign on it the drum is red and the sky is dark and blue there are two people walking on the sidewalk
#
# pic_id -  test_6
# original caption -  a large white house with a brown door sits behind some grass. there are four sheep grazing on the grass in front of the house. the house ahs a gray roof.
# predicted caption -  this is an image of a train the sheep is standing in the grass the sheep is black and white the sheep is standing in a field the grass is made of wood the grass is made of wood the grass is made of wood the grass is very green the grass is very green the sky is blue with white clouds
#
# pic_id -  test_7
# original caption -  a man in a red and yellow t-shirt is holding a wii remote in each of his hands. behind him there is a fireplace which has been painted white. in front of him a light which is on and illuminating the room.
# predicted caption -  a man is standing in a room holding a white wii controller in his hand the man is wearing a white shirt and blue jeans the man is holding a white wii controller and a white laptop on his neck the man is wearing a white shirt and blue jeans the woman is holding a white wii controller in his hand and a white shirt and a black tweed shirt the woman is wearing a black shirt and jeans and a white shirt
#
# pic_id -  test_8
# original caption -  there are three men riding bicycles. two of the men are wearing yellow and the third man has a blue shirt. the two men are way ahead of the third man. the men are bicycling in the bicycle lane. the cars are on the left side of the men.
# predicted caption -  a man is riding a skateboard down a road the man is wearing a black helmet and a black shirt the man is wearing a black helmet and a black shirt the man is wearing a black helmet and a black shirt there is a man riding a bike hiding to the right of the motorcycle there is a man riding a bike ramp on the sidewalk there is a man in a black jacket and a black jacket on the motorcycle
#
# pic_id -  test_9
# original caption -  two cell phones on the table.they both are dark in color a nd are blacberrys.there are three cutting knives.one knife is between the two phones.there is a third phone with a knife lying over it.
# predicted caption -  a peach colored cat is sitting on a white rolling desk the ports on the luggage are white and white the cat has a black collar the device is black and white the cat has a black collar the cord is black and white the cat has a black collar on the top the cord is black and white
#
# pic_id -  test_10
# original caption -  a painted mannequin head sits on a table. it is a feminine head with arched eyebrows a small nose, big eyes and it is wearing a black top hat and a brown wig. to the right of the head is a metal sculpture clock with a white face.
# predicted caption -  a black fluffy clock is sitting on a wooden floor the cat has a black face and a black face the cat has a black face and a black face the cat has a black face and a black face the cat has a black face and a black face the clock is black and white the clock is black and white
#
# pic_id -  test_11
# original caption -  a white and yellow train is on the tracks. there is a large yellow door on the front of the train. there is a platform next to the train.
# predicted caption -  a train is sitting on a track the train is yellow and white the train is white the train is yellow and white the train is yellow and white the train is on the train tracks the train is yellow and white the train is mostly blue the train is mostly blue the train is mostly blue the train is mostly blue the train is mostly blue the train is mostly blue
#
# pic_id -  test_12
# original caption -  a man is sitting on the back of an elephant. they are walking through a very high swamp area. they are being seen from in between the perspective of two logs of a tree.
# predicted caption -  a man is standing in front of a rope the elephant has a white bell on its head the man has a white shirt on the neck of her head is a light brown color the elephant's trunk is wrinkled the elephant's trunk is wrinkled the elephant's trunk is wrinkled the elephant has a long heart on it the man has a black nose on the back of the elephant
#
# pic_id -  test_13
# original caption -  there is a black place mat on top of a wood table. there is a white plate on the mat with food on it. there is a fork on the mat next to the plate. there is an orange towel next to the plate.
# predicted caption -  a white plate is sitting on a table the plate is white and brown the plate is on a table the plate is white and brown the plate is white and brown the plate is on a table the plate is white and brown the plate is white and brown the plate is on a table the plate is white and brown
#
# pic_id -  test_14
# original caption -  a goat has its head turned back and it's looking at something. the goat is white but has a black nose and mouth and black ears. the horns of the goat are pointed upwards and has black tops. the goat is standing in green grass.
# predicted caption -  a large black and white dog is standing on a dirt ground the dog is white and white with a black nose the dog has a black nose and a black nose the dog has a black nose and a black nose the dog has a black nose and a black nose the dog has a black nose and a black nose the dog has a black nose and a black nose
#
# pic_id -  test_15
# original caption -  a woman is walking her dog. she is on a skateboard while she is holding the leash of her dog. she is wearing a gray hoodie and some black shorts.
# predicted caption -  a man is skateboarding outside on a sunny day he is wearing a black shirt and blue jeans the man is wearing a black shirt and blue jeans the man is wearing a black shirt and blue jeans the man is wearing a black shirt and blue jeans the man is wearing a black shirt and blue jeans the man is wearing a black shirt and blue jeans the man is wearing a black shirt and blue jeans
#
# pic_id -  test_16
# original caption -  there are some portable bathrooms sitting near a railroad track. there are some trains sitting on the track. the portable bathrooms are blue with a white roof and the trains are yellow.
# predicted caption -  a train is sitting on a track the train is white and has a red stripe on the side the bumper on the train is white the bumper on the train is white the bumper on the train is white the bumper on the train is white the bumper on the train is white the bumper on the train is white
#
# pic_id -  test_17
# original caption -  a very white bathroom has a very white sink and toilet. the shower curtain that hangs from the ceiling is also white. there is one wall that is all mirrored. the door is made of glass and the faucet is silver. the floor is made of black tile.
# predicted caption -  this is a bathroom the bathroom is void of any the bathroom the bathroom is void of any the walls are white the walls are white the walls are white the walls are white the walls are white the walls are white the walls are white the walls are white the walls are white the walls are white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor is white the floor
#
# pic_id -  test_18
# original caption -  a man is in a black wetsuit. the man is riding a white surfboard. there is a large wave in the water the man is surfing on.
# predicted caption -  a man is surfing on a wave the water is white and has a small shark on the top the man is wearing a black wet suit the man is wearing a black wet suit the man is wearing a black wet suit the man is wearing a black wet suit the man is wearing a wetsuit the wetsuit is white the water is calm and white
#
# pic_id -  test_19
# original caption -  a pizza is on a brown wooden tray. the tray is placed on the stove top. the pizza has melted cheese and spinach on top of it. the stove is white with black burners.
# predicted caption -  a pizza is sitting on a table the pizza is white and brown the pizza is white the pizza is white the pizza is white the pizza is white the pizza is white the pizza is white the pizza is white and brown the pizza is white and brown the pizza is white and brown
#
# pic_id -  test_20
# original caption -  a flood is occuring. there is a lot of water on the road. the hydrant on the sidewalk is red. the garage doors are red in color . there are some pieces of grass growing.
# predicted caption -  a fire hydrant is in the middle of a pathway the fire hydrant is made of wood the bench is made of wood the bench is made of wood the bench is made of wood the bench is made of wood the bench is made of wood the bench is made of wood the wall is made of wood
#
# pic_id -  test_21
# original caption -  there are four airplanes in the sky. there is a small hill under them. there is a field of grass under the airplanes. there are smoke trails coming out from behind the airplanes.
# predicted caption -  a man is flying a kite the kite is white the sheep is white and white the duck has a black nose the duck has a black stripe down the front the silhouette of the plane is white the sky is blue and blue the sky is blue and blue the sky is blue and blue
#
# pic_id -  test_22
# original caption -  there is a large white airplane that is in the sky. there is a silver fence under the airplane. there are light poles on both sides of a fence under the plane.
# predicted caption -  a large white and white bird is flying on a cloudy day the plane is white and has a white stripe down the front and a white face on the front and a white face and a red stripe down the front and a white face and a white tail the plane is a deep blue color with a white appearance the plane is a deep blue color
#
# pic_id -  test_23
# original caption -  a young lady is having a very fun time by herself. this young lady has on very short jean shorts, a turquoise top and some shades on. she is surfing a fake wave on a plastic board and having so much fun.
# predicted caption -  a woman is standing in a chair in a room holding a white and white racket in her hand the man is wearing a white shirt and blue jean shorts the woman is holding a white and white racket in her hand the woman is holding a white and white racket in her hand and a white shirt on her head there is a white and white tarp on the wall behind her
#
# pic_id -  test_24
# original caption -  a man is jumping in the air. the man is holding a green frisbee in his hand. there are trees behind the man.
# predicted caption -  a woman is playing tennis on a grassy field she is wearing a short sleeve shirt and white shorts she is holding a frisbee in her hands a woman is standing on the grass holding a ball in her hand the court is blue and blue with white lines on it the grass is green and blue with a blue roof
#
# pic_id -  test_25
# original caption -  a tennis player has just forehand swung to hit a ball. the player has on a light blue shirt and headband. he has on brown nike shorts and white shoes.
# predicted caption -  a woman is playing tennis on a tennis court playing tennis he is wearing a white shirt and white shorts the man is holding a racket in her hand the court is green and white with white lines on it the court is blue with white lines on it the court is blue with white lines on it
#
# pic_id -  test_26
# original caption -  there is a vase on a table.  the vase has a white enamel base and three flower holders.  in the vase is an assortment of artificial fall colored leaves and berries.  the colors depicted are different shades of orange.  the table appears to be in the backyard of a house.  behind the vase is a picket fence, a sidewalk, some monkey grass, and some pink flowers.  on the other side of the fence the eaves of the neighboring house are seen.
# predicted caption -  a man is sitting on a skateboard the man is wearing a white shirt and blue jeans the man is wearing a shirt the shirt is white the man is wearing a shirt the shirt is white the man is wearing a shirt the shirt is white the man is wearing a shirt the shirt is white the man is wearing a shirt the shirt is white the man is wearing a shirt the shirt is white the man is wearing a shirt the shirt is white the man is wearing a shirt the shirt is white the man is wearing a shirt the shirt is white the man is wearing a shirt the shirt is white the man is wearing a shirt the shirt is white the man is wearing a shirt the shirt is white the man is wearing a shirt the shirt is white the man is wearing a shirt the shirt is white the man is wearing a shirt the shirt is white the man is wearing a shirt the shirt is white the man is wearing a shirt the shirt is white the man is wearing a shirt the shirt is white the man is wearing a shirt the shirt is white the man is wearing a shirt the shirt is white the man is wearing a shirt the shirt is white the man is wearing a shirt the shirt is white the man is wearing a shirt the shirt is white the man is wearing a shirt the shirt is white the man is
#
# pic_id -  test_27
# original caption -  a person is standing on the beach. they are flying a large yellow and red kite. there are small waves in the water. the person is wearing a black wet suit.
# predicted caption -  a person is flying a kite the kite is white the kite is white the kite is white the kite is white the kite is white the kite is flying high in the sky the sky is blue and blue the sky is blue and blue the sky is blue and blue
#
# pic_id -  test_28
# original caption -  a white plate of food. there is rice under a pile of broccoli. there are onions cut up on top of the broccoli.
# predicted caption -  this is a picture of food the food is cooked the asparagus is cooked the food is cooked the food is cooked the food is cooked the pizza is cooked the food is cooked the rice is cooked the rice is cooked the rice is cooked the rice is light brown there are vegetable peas on the broccoli the broccoli is brown and brown there is a fork on the plate the rice is green the broccoli is brown
#
# pic_id -  test_29
# original caption -  a stop sign is on a piece of wood and attached to a round sign that is white, with a red border around the outside. below the stop sign there are two signs in russian. the signs are attached to a rusty metal fence.
# predicted caption -  a close of a stop sign with a big white sign on it the sign is made of concrete and has a directional sign on it the sign is white with white letters and the numbers are blotched instead of the sign the sign is made of wood and has a directional sign on it the sign is made of wood and has a directional sign on it the sign is made of bricks and has a directional sign on it
#
# pic_id -  test_30
# original caption -  a man is playing tennis. he is wearing  a sweatband in his hair. his hair is brown in color. his hair is very long. his uniform is white. he is also wearing white shorts.
# predicted caption -  a man is standing on a tennis court he is wearing a white shirt and white shorts he is holding a racket in her hands the man is wearing a white shirt and white shorts the man is holding a racket in her hands the man is wearing a white shirt and white shorts the tennis court is white
#
# pic_id -  test_31
# original caption -  four sailboats with masts but no sails are lined up along the shore of a lake.  a hill rises beyond them in the sun.  part of the hill is bare rock and dirt and part has low green bushes.  the sky is very blue beyond the hill.
# predicted caption -  a large white bird is standing in the water the boat is a greenish color the boat is a greenish color the boat is a greenish color the boat is a greenish color the boat is a greenish color the boat is a greenish color the water is calm and white
#
# pic_id -  test_32
# original caption -  a man is standing outside flying a black and white kite. he is wearing a white hat on his head, a suit coat, and dark colored pants. a shadow of the man can be seen beside him on the ground. the sky is clear and blue. tall trees are seen below the sky.
# predicted caption -  a man is skateboarding on a grassy field the man is wearing a hunter blue shirt and black shorts the man is wearing a hunter black shirt and black shorts the man is wearing a hunter black shirt and black shorts the man is wearing a hunter black shirt and black shorts the man is wearing a hunter white shirt the man is wearing a hunter white shirt the man is wearing a hunter white shirt the man is wearing a hunter white shirt the man is wearing a hunter white shirt the man is wearing a hunter white shirt the man is wearing a hunter white shirt the man is wearing a hunter white shirt the man is wearing a hunter white shirt the man is wearing a hunter white shirt the man is wearing a hunter white shirt the man is wearing a hunter white shirt the man is wearing a hunter white shirt the man is wearing a hunter white shirt the man is wearing a hunter white shirt the man is wearing a hunter white shirt the man is wearing a hunter white shirt the man is wearing a hunter white shirt the man is wearing a hunter white shirt the man is wearing a hunter white shirt the man is wearing a hunter white shirt the man is wearing a hunter white shirt the man is wearing a hunter white shirt the man is wearing a hunter white shirt the man is wearing a hunter white shirt the man is wearing a hunter white shirt
#
# pic_id -  test_33
# original caption -  five off white sheep are standing on a rocky grassy hill. the stones are medium sized and are grey and white. beyond the sheep is a bright blue body of water and a set of beautiful grass covered mountains and a blue sky.
# predicted caption -  a group of people are standing in the grass in a field the slope is covered with snow the mountains are covered with snow the mountains are white and white the sky is blue with white clouds the sky is blue with white clouds
#
# pic_id -  test_34
# original caption -  a large white truck sits in a parking space in a small parking lot. the trailer of the truck has a cover on it. on the other side of the parking lot are a few more cars. the other cars are parked next to a building that looks to be made of brick. there are a few bare plants in the front of the building.
# predicted caption -  a man is standing outside by a concrete floor the truck is white and has a black license plate on it the man is wearing a black shirt and a black shirt the man is wearing a black shirt and a black shirt the man is holding a black umbrella the umbrella is black the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is
#
# pic_id -  test_35
# original caption -  there is a big yellow sign. the sign is a warning sign. the sign is shaped like a diamond. there is a light above the sign.
# predicted caption -  a large white sign is sitting on a street the sign is black and white the sign is black the sign is black the sign is black the sign is black the sign is black the sign is black the sign is black the sign is black the sign is black the sign is black the sign is black
#
# pic_id -  test_36
# original caption -  an image of a peeled large banana dominates the picture. three men are walking down the street.  the man in the front is by himself while two other men are in close proximity.  two buses are parked along the side of the street.
# predicted caption -  a man is standing in a restaurant the man is wearing a white shirt and blue jeans the man is wearing a white shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt the man is wearing a black shirt
#
# pic_id -  test_37
# original caption -  the scene takes place outdoors in a winter snowy landscape, three persons and a child are interacting. a man is leading a child into the ski lift provider. they are standing by the entrance about to enter, a man in a green jacket seems to the entrance attendant. a building with woodside panelling is above the people. a man is standing in the foreground, wearing an orange jacket. the ground is filled with snow, the people are wearing winter clothes. there are signs above the man and child.
# predicted caption -  a man is standing outside on a skateboard the man is wearing a black jacket and blue jeans the woman is wearing a black jacket and a black jacket the man is wearing a black jacket and a black jacket the man is wearing a black jacket and a black jacket there is a large building behind the man
#
# pic_id -  test_38
# original caption -  a large white cow is grazing in the grass. the cow is in a field with weeds and grass. there are trees behind the cow.
# predicted caption -  a black and white cow is standing in a field in a field the field is made of dry grass and soil there is a small white cow in the field in front of the cow there is a white cow in the middle of the cow the cow has a black tag on it there is a white cow in the grass behind the cow there is a small white cow in the grass behind the cow
#
# pic_id -  test_39
# original caption -  there is a big mountain. there are a lot of trees on the mountain. there are two girls walking along the trail. the trail is made of dirt. they are holding umbrellas in their hands.
# predicted caption -  a man is standing on a hill the hill is covered in snow the sheep is white and white the sheep is standing on a hill the grass is blue and white the sky is blue with white clouds the sky is blue and blue the sky is blue with white clouds
#
# pic_id -  test_40
# original caption -  there is a large strip of grass along a road, with buildings, people, buses, trees and flags. the grass is very green and has something more overgrown like bushes that run along the road. the strip of road that is showing to the right of the picture is black. there are two large buses on the road. one bus is red with yellow words on it and the other is black. there are people in both buses, and along the grass and road. there are large trees running by the roads and buildings in the middle and back of the picture. there are two buildings showing. one building is on a street corner and is white with many stories. the other is to the left and is grey with many stories. there are two flag poles and one of them has a flag hanging on it.
# predicted caption -  this is an image of a bus the bus is parked on a street the bus is white the bus is white the bus is white the bus is white the bus is white the bus is red and white the bus is red and white the bus is red and white the bus is red and white the bus is red and white the bus is red and white there are many windows on the bus the sky is blue
#
# pic_id -  test_41
# original caption -  a menu is see hanging on the wall. the menu is over the kitchen area. there is a range top that has a couple of things on it. on the counter is some fish and chicken.
# predicted caption -  this is a picture of a counter the counter is made of metal the counter is made of metal the counter is white and white the toaster the counter is white the toaster the counter is white the counter is white and white the man is wearing a black apron the man is wearing a black apron the man is wearing a black apron the man is wearing a black apron
#
# pic_id -  test_42
# original caption -  an elephant relaxes in the water. a man lays on the back of the elephant. a few other men stand around the elephant and look at it. the water is a brown color. the men are all wearing swim trunks. the sun is reflecting on the water.
# predicted caption -  this is an image of some animals the water is very nice and the water is murky and murky the water is murky and has a large body of water the water is murky and has a large white tint the water is shining in the water the water is murky and has a small white tint the water is shining in the water the water is murky and has a few ripples on it
#
# pic_id -  test_43
# original caption -  a boy is playing frisbee. the frisbee is white in color. the shorts are red in color. his shirt is black and red. he is wearing white shoes.
# predicted caption -  a man is standing on a grassy field playing soccer outside the man is wearing a white shirt and blue shorts the man is wearing a black shirt and blue shorts the man is wearing a black shirt and blue shorts the man is wearing a black shirt and blue jeans the man is wearing a black shirt and blue jeans the man is wearing a black shirt and blue jeans the man is wearing a black shirt and blue jeans
#
# pic_id -  test_44
# original caption -  a bunch of planes are in formation in the air. one plane is way farther away from the rest. the sky is a pretty blue color and a couple of clouds are seen.
# predicted caption -  a large semi tower is in the middle of a field the sky is blue and blue with a few white clouds in it the sky is blue with white clouds in the sky is a deep blue with a few wispy white clouds in it there is a small mountain behind the house and a blue chimney on the right side of the photo there is a small building with a blue sky and a few trees in the background
#
# pic_id -  test_45
# original caption -  a person with a black shirt on is jumping on a skateboard. there is a boy in a red jacket standing in front of him. there is a black fence behind the people.
# predicted caption -  a man is skateboarding outside on a sunny day he is wearing a black shirt and black shorts the man is wearing a black shirt and black pants the man is wearing a black shirt and black shorts the man is wearing a black shirt and black jeans the man is wearing a black shirt and black jeans the man is wearing a black shirt and black jeans the man is wearing a black shirt and black jeans
#
# pic_id -  test_46
# original caption -  there are many boats in the water. there are small waves in the water around the boats. there is a bird flying in the air above the water. there is a hill on the other side of the water.
# predicted caption -  a man is standing on a beach the person is wearing a wetsuit the man is wearing a wetsuit the man is wearing a wetsuit the man is wearing a wetsuit the wetsuit is black and white the water is calm and white the water is calm and white the sky is blue and gray
#
# pic_id -  test_47
# original caption -  in this image, a downtown business district in an english speaking country is depicted. the image shows a narrow street with sidewalks on both sides, with customers walking up and down the sidewalks and going in and out of stores. the narrow street does not have any cars driving down it, but instead there is a train or streetcar running on rails. the train is white on the top and red on the bottom with a large glass windshield in front and smaller glass windows on the sides. it is coming up to an intersection. at the intersection, there is a sign that indicates only bicycles are allowed on the cross street. all the people in the picture are wearing lightweight jackets, so it must be fall or spring, as there is no snow or rain. there is a store called dreams, and a sign advertising beds, though it is difficult to tell if they are beds for sale or rooms for rent. if i had to guess, i'd say this is an english speaking country in europe.
# predicted caption -  this is a picture of a bus the bus is parked on a sidewalk the bus is white the bus is white the bus is red and white the bus is white the bus is red and white the bus is red and white there are many windows on the bus the bus is red and white there are many windows on the bus the bus is red and white there are many windows on the bus the bus is red
#
# pic_id -  test_48
# original caption -  a bus is on the street. it is currently getting ready to pick some people up and drop some off. the bus is white, purple, and red on the top. the building has a lot of moss on it.
# predicted caption -  a double decker bus is parked on a road the bus is white and white the bus is white and white there is a white bus on the bus ther is a large red bus on the bus the bus is white and white there are people standing on the sidewalk the bus is white there is a large windshield on the side of the bus
#
# pic_id -  test_49
# original caption -  a young boy is walking with a horse. the young boy has on a black sweater with a blue shirt tied around his waist. the horse is a dark brown color and looks very friendly.
# predicted caption -  a man is standing outside on a sunny day the man is wearing a black jacket and a black jacket the man is holding a black frisbee the man is wearing a black jacket and a black shirt the man is holding a black frisbee the man is wearing a black shirt and blue jeans the man is holding a black frisbee the man is wearing a blue shirt and blue jeans
#
# pic_id -  test_50
# original caption -  a sign is on a pole. the pole is green in color. there is an arrow on the sign. the arrow is white in color. there is writing on the sign.
# predicted caption -  a large slab of brick building is on the street the streetlight is red and white the streetlight is pointing to the front of the car the streetlight is red and white the streetlight is pointing to the left of the car the sign is black and white the trees are green and green the trees are green and green
#
# pic_id -  test_51
# original caption -  a vintage pick-up truck is parked at the sidewalk. the truck is beige with black roof. at the sidewalk is a black parking meter. the parking meter is attached to silver pole with blue painted letters on it.
# predicted caption -  a truck is parked on the street the truck is white the truck is white the truck is white the truck is white the truck is white the truck is white the truck is white the truck is white the truck is white the truck is white the truck is black and white the truck is a light brown color
#
# pic_id -  test_52
# original caption -  a man wearing striped swim shorts is standing on sand. there is also a black and white dog standing on the sand. there is a white frisbee in the air above the sand.
# predicted caption -  a man is standing on a beach the man is wearing a black helmet the man is wearing a black helmet the man is wearing a black helmet the man is wearing a black helmet the man is wearing a black helmet the man is wearing a black helmet the man is wearing a black jacket the man is wearing a black jacket the man is wearing a black jacket the man is wearing a black jacket
#
# pic_id -  test_53
# original caption -  there are plates and bowls on top of a table. the table is wooden and there are small bowls in the middle. there is food on the plates. there are knives and forks on top of the plate.
# predicted caption -  a white plate is sitting on a table the table is white and brown there is a plate on the table the crusts are white the crusts of the plate are white the crusts are white the crusts are white the crusts are white the crusts are white
#
# pic_id -  test_54
# original caption -  a group of people have gather around the skateboarding ramp to watch other skateboarder's skate on it. there is one person in the ramp. it looks like that person fell down off of their board.
# predicted caption -  a group of people are standing on a bright brown court one of the men is wearing a white shirt and blue shorts the other man is wearing a blue shirt and blue jeans a man is standing near the man in front of him a man is standing near the man in front of him a man in a blue shirt and a black shirt is standing near the man in front of him a man in a blue shirt and a black shirt is standing behind the man a man in a blue shirt and a black shirt is standing behind the man
#
# pic_id -  test_55
# original caption -  a bunch of donuts are being displayed. the top row of donuts are all glazed types. there is a person waiting in a grey shirt.
# predicted caption -  a woman is standing in a kitchen the toaster is white and white the man is wearing a tight white shirt the other man is wearing a tight white color the other man is wearing a tight white color the other man is wearing a tight white color the other man is wearing a tight white color the other man is wearing a black apron the other man is wearing a black apron the other man is wearing a black apron
#
# pic_id -  test_56
# original caption -  a bag of potato chips is sitting on a couple of tan napkins on an oval plate. there are two half sandwiches on the plate with the chips. the sandwiches have black grill marks on the tops. there is a yellow mug on the table next to the plate.
# predicted caption -  this is a picture of a pastry the box is white the box is powdered sugar the plate is white the box is powdered sugar the sandwich is white the box is on a white pastry the box is on a white pastry the box is on a white pastry the box is on a white table the box is on a white table
#
# pic_id -  test_57
# original caption -  there is a big motorcycle in the parking lot. it looks just like a race car. it is blue and gray in  color. the seats are very big. the wheels are very spaced apart. it doesn't look like a motorcycle.
# predicted caption -  a man is riding a motorcycle the motorcycle is black and white the motorcycle is black the motorcycle is custom on the motorcycle the motorcycle is black the motorcycle is custom on the motorcycle the motorcycle is black there are people standing on the sidewalk the motorcycle is black there are people standing on the sidewalk the motorcycle is black
#
# pic_id -  test_58
# original caption -  a large splash is in front of a wave in the water. there is a large white and black surf board in the water. there is a black dog that is riding on top of the surf board.
# predicted caption -  a man is surfing on a wave the wave is murky and the water is calm and white the wave is crashing on the water the wave is crashing on the water the wave is crashing on the water the wave is crashing on the water the water is shining cloudy
#
# pic_id -  test_59
# original caption -  a black parking meter with a white sign on it. there is a car parked in front of the parking meter. there is a shadow of a tree on top of the car.
# predicted caption -  a black and white smart phone with a collar is on a black pole the tv is on a black pole the sign is locked with a black circle and says sticker the sign is locked in front of a black sign the sign is locked with a black circle and a black circle design the sign is closed and says blurry
#
# pic_id -  test_60
# original caption -  brown baby bears are walking in the grass. there is a large log above them next to two large rocks.
# predicted caption -  a giraffe is standing in a zoo the picture was taken in a nice sunny day the giraffe is brown and white the giraffe is standing on a rock tire the giraffe is brown and brown the giraffe has long brown whiskers the giraffe has a long neck the mane is made of wood the giraffe is brown and brown the giraffe is standing on a rock
#
# pic_id -  test_61
# original caption -  there are four jets flying in the sky together. each jet is leaving a trail of puffy white smoke behind the other one. the sky is a bright blue.
# predicted caption -  a plane is flying in the air the plane is white and white the plane is white and white the plane is white and white the plane is flying high in the sky the plane is flying in the sky the plane is flying in the sky the plane is flying in the sky
#
# pic_id -  test_62
# original caption -  the tall large building is in the city. on the front of the building are many windows. it also has a clocks telling the time of different countries. the sky is blue but mostly cloudy.
# predicted caption -  a clock is sitting on a street the clock's hands are black and black the clock's hands are black and black the clock's hands are black and black the clock's hands are black and white the clock's hands are black and white the clock's hands are black and white the clock's hands are black and white
#
# pic_id -  test_63
# original caption -  a plate with a colorful rim on it is sitting on a table. there is a piece of chicken on the plate with salad next to it. there is also a pile of french fries on the plate.
# predicted caption -  a white plate is sitting on a table the plate is white and brown the food is on a table the plate is white the plate is white the plate is made of marbled the food is white the plate is made of wood the food is white the food is sliced in a white napkin
#
# pic_id -  test_64
# original caption -  a display window is seen with women's underwear on white mannequins inside in a mall. beside the window there is a toy table with chairs around it which three plastic bears are sitting. there is a toy teapot with slots for coins so children can ride with the bears.
# predicted caption -  a bunch of groceries are sitting on a table the tablecloth is made of wood the tissue closest to the camera is white the strawberries are apricots the tissue closest to the camera is white the strawberries are apricots the tissue closest to the camera is white the grapes are white the apples are white the apples are white
#
# pic_id -  test_65
# original caption -  a piece of wood is sitting on a counter. there is a knife with a black handle on top of the wood. there is a white plate of food behind the wood.
# predicted caption -  this is an image of a pet the table is a simple the dog is a simple white color the person is wearing a black shirt the shirt is white the donut is white the donut is white the donut is white the donut is white the person is wearing a black shirt the person is wearing a black shirt the shirt is white the person is wearing a black shirt the person is wearing a black shirt the person is wearing a black shirt the person is wearing a black shirt the person is wearing a black shirt the person is wearing a black shirt the person is wearing a black shirt the person is wearing a black shirt the person is wearing a black shirt the person is wearing a black shirt the person is wearing a black shirt the person is wearing a black shirt the person is wearing a black shirt the person is wearing a black shirt the person is wearing a black shirt the person is wearing a black shirt the person is wearing a black shirt the person is wearing a black shirt the person is wearing a black shirt the person is wearing a black shirt the person is wearing a black shirt the person is wearing a black shirt the person is wearing a black shirt the person is wearing a black shirt the person is wearing a black shirt the person is wearing a black shirt the person is wearing a black shirt the person is wearing a black shirt
#
# pic_id -  test_66
# original caption -  a tall brick tower has two clocks on separate sides of the tower walls.  the clocks on the tower have roman numerals and gold clock hands.  the center of the clock is burgundy and the outer part of the clock is blue.  the tower has a narrowing tiled and reddish steeple at the tower top. black metal grills cover arched window openings under the clock.  full view of the clock is obstructed by stray green leaves on thin brown branches.  the sky is white with clouds.
# predicted caption -  a cat is standing on a bench the parrot is white and white the parrot has a backing on the front of it the parrot is ted brown and white the parrot has a backing on the front of it the parrot is ted brown and white the parrot has a backing on it the parrot is white and white the clock is made of wood
#
# pic_id -  test_67
# original caption -  a person is jumping in the air on a snowboard. there is a ski lift behind them. there are trees next to the ski lift. there is a lot of snow on the ground under them.
# predicted caption -  a person is standing on a snow covered hill he is wearing a black jacket and black pants the snowboard is white and white the skier is wearing a black jacket and black pants the person is wearing a black jacket and a black jacket the person is wearing a black jacket and a black jacket
#
# pic_id -  test_68
# original caption -  a woman is playing some tennis. her hat is white in color. she is wearing a skirt. the skirt is white in color.
# predicted caption -  a man is playing tennis on a tennis court playing tennis he is wearing a white shirt and white shorts the man is holding a racket in his hands the court is blue with white lines on it the court is green and white the court is green and white the court is green with white lines on it
#
# pic_id -  test_69
# original caption -  a kitchen that is empty isn't being used by anyone. the counters are clean and empty. the grill is black and has nothing on it.
# predicted caption -  this is a picture of a kitchen the kitchen is made of wood the cabinets are white and white there is a white microwave in the kitchen the cabinets are white there is a white microwave in the kitchen the cabinets are white there is a black and white microwave hanging above the counter there is a black microwave hanging above the counter there is a black microwave hanging above the counter
#
# pic_id -  test_70
# original caption -  a brown teddy bear is sitting in a window sill. there is a book on its lap. there is a white bar in front of the bear. there is a window behind the bear.
# predicted caption -  a cat is sitting on a laptop compartment on a laptop compartment on a table the cat is brown and has a black nose the cat has a black collar and a black collar the cat is holding a piece of food on the right hand the cat is brown and has a black collar around the collar the cat is holding a piece of food on the right hand
#
# pic_id -  test_71
# original caption -  a woman in a white shirt and red skirt is playing tennis. she is swinging a tennis racket a ball. there is a black fence behind the woman.
# predicted caption -  a woman is playing tennis on a tennis court she is wearing a white shirt and white shorts she is holding a racket in her hands she is wearing a white shirt and white shorts she is holding a racket in her hands a woman is standing on the court watching the woman the court is blue with white lines on it
#
# pic_id -  test_72
# original caption -  three caucasian men are standing against a white wall. they are all wearing black shirts. the man on the far left is holding a white video game controller in his right hand. he has brown hair, and a brown beard and mustache. his shirt has long sleeves. the man in the middle has dark hair that is thinning around his temples. his arms are crossed across his chest, and his right hand is covering his mouth. the man on the far right is wearing a black sweatshirt with gray lettering. he also has a white video game controller in his right hand. he has brown hair, and brown facial hair.
# ...
# predicted caption -  a clock tower is in the middle of a city the building is made of bricks the clock is white and white the clock is white the clock is white the clock is white the clock is white the clock is white the clock is white the clock is made of bricks
#
# pic_id -  test_912
# original caption -  the street runs directly beneath the red-and-yellow arch with the "towne center" sign at its apex.  a shopping center is far in the distance behind the sign, and between the sign and the buildings is a vast, mostly empty parking lot.  more cars are visible toward the buildings, whereas there are very few in the proximity of the arch/sign.  just before the red arch is a street sign that says "end of city street".  a sidewalk follows the road on its right, and just a few plants hint at a larger bit of decoration that's mostly unseen.  the road is appropriately painted with direction paint - yellow lane lines and brake-here marks on the road that goes off to the left from the arch.
# predicted caption -  this is a city street there are two signs on the street the street is red and white the street is red and white there are two signs on the side of the street there are two signs on the side of the street there are two lights on the street the lights are red and white the lights are red and white the lights are red and white the sky is cloudless and cloudless
#
# pic_id -  test_913
# original caption -  this is an image of a table. the table has many items on top. the items are strewn throughout the table. the table is covered in a white cloth. there is a tiny pair of scissors on the table. the scissors are metal and silver. the equipment looks to be medical equipment. there is a shoulder bag that is black on the table.
# predicted caption -  a woman is laying on a bed the bed is white and white the cat is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman is wearing a black shirt the woman
#
# pic_id -  test_914
# original caption -  three people are sitting in a room. a man wearing a green t-shirt is looking to his right. he is wearing glasses. on the dresser behind him is a flower arrangement. to the right of that is a guitar case leaning against the wall.  a woman with long brown hair, a pink shirt and blue jeans is sitting next to the man. she is holding a toy wheel, perhaps from a video game, in her hands. the man sitting next to her on her left is holding a finger to his ear. a photo collage is on the wall.
# predicted caption -  a woman is sitting in a room holding a wii wii controller in her right hand the woman is wearing a white shirt and blue pants the woman is wearing a black shirt and black pants the woman is wearing a black shirt and black pants the woman is wearing a black shirt and a black shirt and a black tie
#
# pic_id -  test_915
# original caption -  a man with black hair is wearing a white shirt and a red tie is eating a waffle with his hand and reading the weekday funny paper of a newspaper. the man is sitting on a wooden chair that has checkered wooden slats on the back. there is a round white and blue plate on the white tablecloth on the table. their is a window at the end of the table showing a deck outside.
# predicted caption -  a man is sitting at a table he is wearing a white shirt and blue shirt the woman is wearing a blue shirt and a white shirt the woman is wearing a blue shirt and a blue shirt the woman is wearing a blue shirt and a black shirt the woman is wearing a black shirt and a black shirt
#
# pic_id -  test_916
# original caption -  a black cat is on the brown desk. the cat is on the border of the desk. a glass with black drink is on back the cat. behind the cat there is a  laptop open with a blue screen. on the screen of the laptop there is icons color white on the right. next to the wall there is a black box and a tan horizontal box.
# predicted caption -  a man is sitting on a laptop computer a laptop computer is sitting on top of the laptop the laptop is sitting on a table the desk is white and white the laptop is printing a modem on the desk the desk is black and white the chairs are black and white the chairs are tangled on a table the desk is black and white
#
# pic_id -  test_917
# original caption -  some of the trees in the distance are have green leaves while most of the them do not have leaves and are brown. there is fence in the distance as well. the grass in the photo is brown and is low. there are two large black and white zebras standing in the brown grass field. the zebra closest tot the camera is grazing on the brown grass.
# predicted caption -  this is an image of a zebra the zebra is standing in the grass the zebra has a white belly the zebra has a white belly the zebra has a white belly the zebra has a white belly the zebra has a white belly the zebra has a shadow on the back of the zebra
#
# pic_id -  test_918
# original caption -  there is a large man wearing a gray tee shirt and khaki colored shorts standing barefoot on grass and holding a kite handle. the kite is blue and white and is off the ground about a foot and a half. there is a lamppost along side a path behind the man, and lush trees growing behind that. in the distance, there is a building behind the trees and two cars parked along side the street in front of the building.
# predicted caption -  a man is standing on a grassy field he is wearing a short sleeve shirt and camo pants the man is wearing a short sleeve shirt and camo pants the man is holding a white frisbee in his hand and he is wearing a white shirt and black shorts the man is wearing a blue shirt and black shorts a white trashcan can be seen behind the trees
#
# pic_id -  test_919
# original caption -  cattle are wading in a body of water. the cows are brown and white. one solid brown cow has large horns. there is a white cow on the bank drinking water alone. there is a small patch of land in the water near the cows that is covered in tall green grass. the water is calm except for a few ripples. there are trees past the cows with only a few brown leaves.
# predicted caption -  a small river is perched on a dirt road the water is calm and has a few small green bushes in the background the trees are created from the water and the trees are created from the water and the trees are created from the trees and the trees are created from the trees and the trees are created from the trees
#
# pic_id -  test_920
# original caption -  busses are parked on a grassy field. the bus in the foreground is a red double-decker with the number 229 on it. the back door is open but a white strip of material is across the opening blocking the entrance. to the right is white and red bus that has the name chalkwell advertised on the back. next to that is a mostly yellow double-decker.
# predicted caption -  a bus is parked on a road the bus is white and white the bus is white and white the bus is white there is a large windshield on the bus the bus is white there is a large windshield on the bus the bus is white there is a large windshield on the bus the bus is white there is a large windshield on the bus
#
# pic_id -  test_921
# original caption -  a small, round, white plate is sitting on a light wood surface. brown crumbs left over from a meal are scattered on the plate, and one chopstick sits on the edge of the plate. a black plastic fork is next to the chopstick, as well as some small torn pieces of paper. a used tea bag sits next to the fork.
# predicted caption -  this is a picture of a pet the pet is a pet the pet is a pet the pet is a simple white pastry the drawer is faded the cat is white the cat is sitting on a white plate the drawer is white the cat is sitting on a white table the drawer is white the cat is wearing a black collar the knife is white the cat is wearing a black shirt the knife is white the cat is wearing a black shirt the knife is white the cat is wearing a black shirt the knife is white the cat is wearing a black shirt the knife is white the cat is wearing a black shirt the knife is white the cat is wearing a black shirt the knife is white the cat is wearing a black shirt the knife is white the cat is wearing a black shirt the knife is white the cat is wearing a black shirt the knife is white the cat is wearing a black shirt the knife is white the cat is wearing a black shirt the knife is white the cat is wearing a black shirt the knife is white the cat is wearing a black shirt the knife is white the cat is wearing a black shirt the knife is white the cat is wearing a black shirt the knife is white the cat is wearing a black shirt the knife is white the cat is wearing a black shirt the knife is white the cat is wearing a black
#
# pic_id -  test_922
# original caption -  this is a photo of three young boys wearing cubs uniforms, how unfortunate. they are ready to play a baseball game, as two of the boys are wearing baseball mitts and one of the boys is even wearing war paint. the boy in front looks very happy, which is to be expected when playing team sports. go team.
# predicted caption -  a man is standing on a baseball court he is wearing a black helmet and white pants the man is wearing a black helmet and a black helmet the man is wearing a black helmet and a black helmet the man is wearing a black helmet and a black helmet the field is green and white the grass is made of dirt
#
# pic_id -  test_923
# original caption -  there is a woman, in a brown jacket, with a fur collar on it. the woman has black hair with silver streaks in it. there is a big brown bear, in a cage. the woman is kissing the bear on his nose. the bear has fluffy brown hair and a black nose. the bear and the woman are in a building and there is snow on the ground outside. there are trees in the background.
# predicted caption -  a man is standing in a room the man is wearing a blue shirt and blue jeans the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has short brown hair the man has
#
# pic_id -  test_924
# original caption -  this is a picture of a stream. the stream is murky green and brown dirty water. there are animals walking in the stream. the animals are cows. the cows are large. the cows are black. the cow in the front has long horns. the horns are sharp. the horns are gray. there are bright green lush and leafy plants along the side of the stream.
# predicted caption -  this is an image of a baby the bear is a baby the bear is furry and has a black nose the trunk is made of wood the bear is furry and has a black nose the trunk is made of wood the bear is furry and has a black nose the trunk is made of wood the grass is made of wood
#
# pic_id -  test_925
# original caption -  this is a black and white photograph of a very old biplane taking off from a flat field. there is some sort of crop growing in the field, but it is indiscernable. the plane itself says "america" on its side. there is a star emblem on its tail as well as underneath the visible wing. the plane is only about 20 feet off the ground.
# predicted caption -  a man is standing outside on a sidewalk the man is wearing a black shirt and black pants the man is wearing a black shirt and black pants the man is wearing a black shirt and black pants the man is wearing a black shirt and black pants the man is wearing a black shirt and black pants the man is wearing a black shirt and jeans
#
# pic_id -  test_926
# original caption -  there are three trains in the image. the buildings are short and some are tall. the clouds in the sky are white. there are tall poles near the train. the trains are on the train tracks. the train is red and white. there are windows on the trains. there is a bridge above the trains. there is a fence along the bridge.
# predicted caption -  this is an image of a train the train is white and has a white propeller on the front the train is white and has a red stripe down the front the train is white and has a red stripe on the front the train is white and has a white roof on the front of it there are two large white lights on the front of the train the sky above the train is blue
#
# pic_id -  test_927
# original caption -  a flock of white sheep are grazing on both green and brown grass, in a pasture. a rooster is behind the flock, standing in a narrow dirt road. some of the sheep are also in the road. the dirt road curves around and then straightens out to the left, going all the through to into the background. a few sheep are lying on the green grass, next to a wire mesh fence, and a planted field of green vegetables are behind the grazing sheep.
# predicted caption -  a giraffe is sitting on a bench the bench is made of wood the bench is made of wood the bench is made of wood the bench is made of wood the bench is made of wood the bench is made of wood the bench is made of wood the bench is made of wood
#
# pic_id -  test_928
# original caption -  two people stand on the sand holding a big c-kite. the c-kite is color red, orange and green. the men wears black clothes. shadows are cast on the ground. there are foot prints are on the sand. on front the men there is a body of water. next to the body there are three people. behind the body of water there are small hills.
# predicted caption -  a man is standing on a beach the man is wearing a wetsuit the man is wearing a wetsuit the man is wearing a wetsuit the wetsuit is black and white the man is wearing a wetsuit the wetsuit is black and white the man is wearing a wetsuit the wetsuit is black and white the man is wearing a wetsuit the wetsuit is black and white the man is wearing a wetsuit the wetsuit is black and white the man is wearing a wetsuit the wetsuit is black and white the man is wearing a wetsuit the wetsuit is black and white the man is wearing a wetsuit the wetsuit is black and white
